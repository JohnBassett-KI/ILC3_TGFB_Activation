# %%
"""
This file is altered from its original so that more than 2000 genes are retained in the final gene-set
original file: Downsample_integrate.ipynb
"""
import numpy as np
import pandas as pd
import anndata as ad
import scanpy as sc

# %%
import bbknn
import matplotlib.pyplot as plt

# %%
#load data from adult large intestine
dataPath  = 'gca_adult_largeInt.h5ad'
adata = sc.read_h5ad(dataPath)

# %%
# load names of good cells from external QC
cellPath = 'cell_names_152.csv'
cellNames = pd.read_table(cellPath)
cellNames=cellNames.x

# %%
#subset data to only cells stored in cellnames
adata = adata[cellNames, :]

# %%
sc.pl.scatter(adata, x='total_counts', y='pct_counts_mt', color = 'Integrated_05')
sc.pl.scatter(adata, x='total_counts', y='n_genes_by_counts', color  = 'Integrated_05')
# Out:
# /home/johbas/.local/.conda/envs/gcAtlas/lib/python3.9/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
sc.pp.highly_variable_genes(adata, flavor='seurat', n_top_genes=2000)

# %%
adata.raw = adata

# %%
adata.X
# Out:
# <5863x33538 sparse matrix of type '<class 'numpy.float32'>'
# 	with 9066527 stored elements in Compressed Sparse Row format>

# %%
#adata=adata[:,adata.var.highly_variable]
#genes should not be removed for running cellphone db

# %%
sc.pp.regress_out(adata, ['total_counts', 'pct_counts_mt'])

# %%
#sc.pp.scale(adata, max_value=10)
#data should not be scaled for running cellphone db

# %%
sc.pp.pca(adata)

# %%
bbknn.bbknn(adata)

# %%
sc.tl.leiden(adata)
bbknn.ridge_regression(adata, batch_key=['batch'], confounder_key=['leiden'])
sc.tl.pca(adata)
bbknn.bbknn(adata, batch_key='batch')
bbknn.bbknn(adata, batch_key='Fraction')

# %%
sc.pp.neighbors(adata,n_neighbors = 10, n_pcs=40)
sc.tl.umap(adata)

# %%
plt.rcParams['figure.figsize' ] = [18, 12]

# %%
sc.pl.umap(adata, color = 'Integrated_05', legend_loc = 'on data', legend_fontsize='x-small', legend_fontweight='medium', legend_fontoutline=1.5)

# %%
adata.X
# Out:
# array([[-6.44100747e-05,  0.00000000e+00,  0.00000000e+00, ...,
#         -1.90522661e-02,  0.00000000e+00,  0.00000000e+00],
#        [-4.94223037e-05,  0.00000000e+00,  0.00000000e+00, ...,
#         -2.16826770e-02,  0.00000000e+00,  0.00000000e+00],
#        [-4.40258164e-05,  0.00000000e+00,  0.00000000e+00, ...,
#         -1.78051311e-03,  0.00000000e+00,  0.00000000e+00],
#        ...,
#        [ 1.00440999e-04,  0.00000000e+00,  0.00000000e+00, ...,
#         -2.86155572e-02,  0.00000000e+00,  0.00000000e+00],
#        [-6.27317288e-05,  0.00000000e+00,  0.00000000e+00, ...,
#         -2.45980924e-02,  0.00000000e+00,  0.00000000e+00],
#        [ 1.14655789e-04,  0.00000000e+00,  0.00000000e+00, ...,
#         -3.13904924e-02,  0.00000000e+00,  0.00000000e+00]])

# %%
adata.write('gca_downsamp152_int_expanded.h5ad')
